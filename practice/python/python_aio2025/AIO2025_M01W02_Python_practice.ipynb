# %% [markdown]
# <a href="https://colab.research.google.com/github/mylethidiem/zero-to-hero/blob/main/AIO2025/W01/M01_Python_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #16/07/2025 revise Module 1
# # w02

# %% [markdown]
# ### Tuples

# %%
#### Constructing tuples
# Để tạo một tuple, đặt các giá trị trong ngoặc:
t = (1, 2, 3)

print(t[0])
print(t[1])
print(t[2])

# %%
# Cũng có thể tạo một tuple không có dấu ngoặc đơn, bằng cách sử dụng dấu phẩy:
t = 1, 2
print(t)
print(type(t))

# %%
# Nếu bạn muốn tạo một tuple với một phần tử duy nhất, bạn phải sử dụng dấu phẩy:
singleton = (1, )
singleton

# %%
var1 = (1 + 2) * 5
print(type(var1), ' ', var1)

var2 = (1)
print(type(var2), ' ', var2)

var3 = (1,)
print(type(var3), ' ', var3)

# %%
# Bạn có thể lặp lại một tuple bằng cách nhân một tuple với một số:
t = (1,) * 5
print(t)

# %%
# Lưu ý rằng bạn có thể nối các bộ dữ liệu và sử dụng phép gán tăng giá trị (* =, + =):
t1 = (1, 0)
print(t1)

t1 += (2,)
print(t1)

# %%
#### Tuple methods
t = (1,2,3,1)
count = t.count(1)
index = t.index(2)

print(count)
print(index)

# %%
t.index(2)

# %%
####  Interests of tuples
#### Tuples cặp khóa / giá trị để xây dựng dictionary
d = dict([('jan', 1), ('feb', 2), ('march', 3)])

print(d['jan'])
print(d['feb'])
print(d['march'])

# %%
#### get multiple values
x1,y1,z1   = ('a','b','c')
(x2,y2,z2) = ('a','b','c')
(x3,y3,z3) = range(3)

print(x1)
print(x2)
print(x3)

# %%
x1,y1,z1   = ('a','b','c')
(x2,y2,z2) = ('a','b','c')
print(x1)
print(x2)

# %%
(x,y,z) = range(3)
print(x,y,z)

# %%
a = range(3)
print(type(a))

# %%
d = {'first':'string value', 'second':1}
for a in d:
    print(a)

# %%
d = {'first':'string value', 'second':[1,2]}
items = d.items()
print('items:', items)
for k,v in items:
    print(k, v)

# %%
#### Tuple Unpacking

data = (1,2,3)
x,y,z = data
print(x)

# %%
#### Tuple can be use as swap function
x = 4
y= 5
print(x,y)
x,y=y,x
print(x,y)

# %%
def swap(v1, v2):
    (v2, v1) = (v1, v2)
    return (v1, v2)

v1 = 2
v2 = 3
(v1, v2) = swap(v1, v2)

# print
print(v1)
print(v2)

# %%
### Misc
# Length
# Tìm chiều dài của một tuple, bạn dùng phương thức len():
t = (1, 2, 3, 4)
len(t)

# %%
# Slicing (extracting a segment)
data = (1, 2, 3, 4, 5)
print(data[2:])
print(data[::-1])

# %%
# Copy a tuple
t = (1, 2, 3, 4, 5)

new_t = t.copy()
print(new_t)

# %%
# Tuple are not fully immutable
t = (1, 2, [3, 10])
t[2][0] = 9
print(t)

# %%
t = (1, 2, 3, 4, 5)
t[2] = 9
print(t)

# %%
# tuple to str
data = (1, 2, 3, 4, 5)
data_str = str(data)
print(data_str)
print(type(data_str))

# %%
print(data_str[0])

# %%
t = (1, 2, 3, 4, 5)

print(min(t))
print(max(t))
print(sum(t))

# %%
t = (4, 7, 3, 9, 6)
t_s = sorted(t)
print(t_s)

# %%
t1 = (1, 2, 3, 4, 5)
t2 = ('a', 'b', 'c', 'd', 'e')

print(t1)
print(t2)

t3 = zip(t1, t2)
for x,y in t3:
    print(x, y)

# %%
import math

def quadratic_equation(a, b, c):
    '''
    This function aims at solving the quadratic equation
    a, b, c --- three parameters and a =! 0
    '''
    # compute delta
    delta = b*b - 4*a*c

    if delta < 0:
        return ()
    elif delta == 0:
        x = (-b + math.sqrt(delta))/(2*a)
        return (x,)
    else:
        x1 = (-b + math.sqrt(delta))/(2*a)
        x2 = (-b - math.sqrt(delta))/(2*a)
        return (x1,x2)

result = quadratic_equation(a=5, b=0, c=1)
print(type(result))
print(len(result))
print(result)

# %%
result = quadratic_equation(a=4, b=4, c=1)
print(type(result))
print(len(result))
print(result)

# %%
result = quadratic_equation(a=4, b=4, c=1)
result[0] = 1

# %%
# tuple and zip

x_data = [1, 2, 3]
y_data = [5, 6, 7]
data = zip(x_data, y_data)
print("data = ",data)
# print
for d in data:
    print(d)
    print(type(d))

# %%
# memory comparison
import sys

aList  = [3, 4, 5, 6, 7]
aTuple = (3, 4, 5, 6, 7)

print(sys.getsizeof(aList))
print(sys.getsizeof(aTuple))

# %%
# convert from tuple to list
aTuple  = (3, 4, 5, 6, 7)
aList = list(aList)

print(aList)
print(type(aList))

# %% [markdown]
# ### Set

# %%
# create a set
animals = {"cat", "dog", "tiger"}

print(type(animals))
print(animals)

# %%
# create a set
a_set = {"cat", 5, True, 40.0}

print(type(a_set))
print(a_set)

# %%
# No duplication
animals = {"cat", "dog", "tiger"}
print(animals)

animals.add("cat")
print(animals)

# %%
# copy
animals = {"cat", "dog", "tiger"}
print("Animals:", animals)

a_copy = animals.copy()
print("Copy:", a_copy)

# %%
# accessing items
animals = {"cat", "dog", "tiger"}
for animal in animals:
    print(animal)

# %%
# not support indexing
animals = {"cat", "dog", "tiger"}
print(animals[1])

# %%
# add an item
animals = {"cat", "dog", "tiger"}
animals.add("bear")
print(animals)

# %%
# insert a set to another set
animals = {"cat", "dog", "tiger"}
animals.update({"chicken","Duck"})
print(animals)

# %%
# join two sets
set1 = {"cat", "dog"}
set2 = {"duck", "tiger"}

set3 = set1.union(set2)
print(set3)

# %%
# remove an item
animals = {"cat", "dog", "tiger"}
animals.remove("dog")
print(animals)

# %%
# remove an item
animals = {"cat", "dog", "tiger"}
animals.discard("tiger")
print(animals)

# %%
# remove an item
animals = {"cat", "dog", "tiger"}
animals.remove("duck")
print(animals)

# %%
# remove an item
animals = {"cat", "dog", "tiger"}
animals.discard("duck")
print(animals)

# %%
# create a set
a_list = [1, 2, 3]
a_set  = {"cat", a_list}
print(a_set)

# %%
# difference

set1 = {"apple", "banana", "cherry"}
set2 = {"pineapple", "apple"}

set3 = set1.difference(set2)

print(set3)

# %%
# difference_update

set1 = {"apple", "banana", "cherry"}
set2 = {"pineapple", "apple"}

set1.difference_update(set2)

print(set1)

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"pineapple", "apple"}

print(id(set1))
set1.difference_update(set2)

print(set1)
print(id(set1))

# %%
# symmetric_difference

set1 = {"apple", "banana", "cherry"}
set2 = {"pineapple", "apple"}

set3 = set1.symmetric_difference(set2)

print(set3)

# %%
# symmetric_difference_update

set1 = {"apple", "banana", "cherry"}
set2 = {"pineapple", "apple"}

set1.symmetric_difference_update(set2)

print(set1)

# %%
# AND (&)

set1 = {1, 2, 3}
set2 = {3, 4, 5}

print(set1 & set2)

# %%
# OR (|)

set1 = {1, 2, 3}
set2 = {3, 4, 5}

print(set1 | set2)

# %%
# XOR (^)

set1 = {1, 2, 3}
set2 = {3, 4, 5}

print(set1 ^ set2)

# %%
# subtraction (-)

set1 = {1, 2, 3}
set2 = {3, 4, 5}

print(set1 - set2)

# %%
# set comprehension

aSet = {i*i for i in range(10)}
print(aSet)

# %% [markdown]
# Conversion

# %%
# convert from set to list
aSet = {1, 2, 3, 4, 5}

aList = list(aSet)
print(aList)
print(type(aList))

# %%
# convert from set to tuple
aSet = {1, 2, 3, 4, 5}

aTuple = tuple(aSet)
print(aTuple)
print(type(aTuple))

# %%
# convert from list to set
aList = [1, 2, 3, 2, 1]

aSet = set(aList)
print(aSet)
print(type(aSet))

# %%
# convert from tuple to set
aTuple = (1, 2, 3, 2, 1)

aSet = set(aTuple)
print(aSet)
print(type(aSet))

# %% [markdown]
# Application for set

# %%
# kết nối với file
a_file = open('data.txt','r')

# read content
data = a_file.read()
print(data)

# Đóng kết nối với file
a_file.close()

# %%
data = data.replace('.', '')
print(data)

# %%
data = data.replace(',', '')
print(data)

# %%
data = data.lower()
print(data)

# %%
data = data.split()
print(data)
print(len(data))

# %%
data = set(data)
print(data)
print(len(data))

# %%
for index, value in enumerate(data):
    print(index, value)

# %%
dic_data = {value:index for index, value in enumerate(data)}

# %%
print(dic_data["a"])

# %% [markdown]
# ### Dictionary

# %%
keys   = ['a', 'b', 'c']
values = [1, 2, 3]

a_dictionary = {(k,v) for (k,v) in zip(keys,values)}
print(a_dictionary)
print(type(a_dictionary))

# %%
parameters = {'learning_rate': 0.1,
              'optimizer': 'Adam',
              'metric': 'Accuracy'}

print(parameters)
print(type(parameters))

# %%
parameters = {'learning_rate': 0.1,
              'optimizer': 'Adam',
              'metric': 'Accuracy'}

keys   = parameters.keys()
print(keys)

for key in keys:
    print(key)

# %%
keys = parameters.keys()
for key in keys:
    print(key)

# %%
values = parameters.values()
for value in values:
    print(value)

# %%
parameters = {'learning_rate': 0.1,
              'optimizer': 'Adam',
              'metric': 'Accuracy'}

items = parameters.items()
for key, value in items:
    print(key, value)

# %%
parameters = {'learning_rate': 0.1,
              'optimizer': 'Adam',
              'metric': 'Accuracy'}

for key in parameters:
    print(key)

# %%
parameters = {'learning_rate': 0.1,
              'optimizer': 'Adam',
              'metric': 'Accuracy'}

value = parameters.get('learning_rate')
print(value)

print('\nAfter using get() function')
print(parameters)

# %%
parameters = {'learning_rate': 0.1,
              'optimizer': 'Adam',
              'metric': 'Accuracy'}

value = parameters.pop('learning_rate')
print(value)

print('\nAfter using pop() function')
print(parameters)

# %%
parameters = {'learning_rate': 0.1,
              'optimizer': 'Adam',
              'metric': 'Accuracy'}

value = parameters.get('algorithm')
print(value)

# %%
parameters = {'learning_rate': 0.1,
              'optimizer': 'Adam',
              'metric': 'Accuracy'}

value = parameters.pop('algorithm')

# %%
parameters = {'learning_rate': 0.1,
              'optimizer': 'Adam',
              'metric': 'Accuracy'}

item = parameters.popitem()

print(item)
print(parameters)

# %%
parameters = {'learning_rate': 0.1,
              'metric': 'Accuracy'}

print('Before using clear() function')
print(parameters)

parameters.clear()

print('\nAfter using clear() function')
print(parameters)

# %%
parameters = {'learning_rate': 0.1,
              'metric': 'Accuracy'}

del parameters['algorithm']

# %%
parameters = {'learning_rate': 0.1,
              'metric': 'Accuracy'}

a_copy = parameters.copy()
a_copy['learning_rate'] = 0.2

print(parameters)
print(a_copy)

# %%
parameters = {'learning_rate': 0.1,
              'metric': 'Accuracy'}

parameters['learning_rate'] = 0.2
print(parameters)

# %%
for key in parameters:
    print(key, parameters.get(key))

# %%
d = {'first':'string value', 'second':[1,2]}
keys = d.keys()
values = d.values()

print(keys)
print(values)

# %%
d = {'first':'string value', 'second':[1,2]}
d.values()

# %%
d = {'first':'string value', 'second':[1,2]}
print(d['first'])
print(d['second'])

# %% [markdown]
# Ngoài các phương thức key và value, còn có phương thức trả về danh sách các mục có dạng (key, value).
# Những phương thức khác không return theo bất kỳ thứ tự cụ thể nào:

# %%
d = {'first':'string value', 'second':[1,2]}
items = d.items()

print('items:', items)
for k,v in items:
    print(k, v)

# %%
d = {'first':'string value', 'second':[1,2]}
d._contain_('first')

# %% [markdown]
# Phương thức iteritems hoạt động theo cách tương tự, nhưng trả về một trình vòng lặp thay vì danh sách.
# Để hiểu thêm các bạn xem phần ví dụ:
#
# Bạn có thể kiểm tra sự tồn tại của một khóa cụ thể bằng has_key:

# %% [markdown]
# Biểu thức d.has_key (k) tương đương với k trong d. Để nhận được giá trị tương ứng với một khóa cụ thể, hãy sử dụng get hoặc pop:

# %%
d = {'first':'string value', 'second':[1,2]}
value = d.get('first')

print(value)
print(d)

# %%
d = {'first':'string value', 'second':[1,2]}
value = d.pop('first')

print(value)
print(d)

# %%
print(d)

# %%
d = {'1':'value1', '2':'value2', '3':'value3', '4':'value4'}
item = d.popitem()

print(item)
print(d)

# %%
d1 = {'a': [1,2]}
d2 = d1
d2['a'] = [1,2,3,4]
d1['a']

# %%
d1 = {'a': [1,2]}
d2 = d1.copy()

print('d1:', d1)
print('d2:', d2)

# %%
d1 = {'a': [1,2], 'b': 5}
d2 = d1.copy()

# thay đổi giá trị d2 sẽ ảnh hưởng đến d1
d2['a'][0] = 3
d2['a'][1] = 4

print('d1:', d1)
print('d2:', d2)

# %%
import copy

d1 = {'a': [1,2], 'b': 5}
d2 = copy.deepcopy(d1)

# thay đổi giá trị d2
d2['a'][0] = 3
d2['a'][1] = 4

print('d1:', d1)
print('d2:', d2)

# %%
d = {'a': [1,2], 'b': 5}
print(d)

d.clear()
print(d)

# %%
d = {'a': [1,2], 'b': 5}
print(d)

del d['a']
print(d)

# %%
d = {'a': [1,2], 'b': 5}
print(d)

del d
print(d)

# %%
d = {'a':1, 'b':2, 'c':3}
del d['a']
print(d)

# %%
d = {'a':1, 'b':2, 'c':3}
d.clear()
print(d)

# %%
d1 = {'a': [1,2]}
d2 = d1.copy()
d2.setdefault('third', '')
d2['third']
print(d2)

# %%
d = {'a':1, 'b':2, 'c':3}

d2.setdefault('third', '')

# %%
d1 = {'a': [1,2]}
d2 = d1.copy()
d2.fromkeys(['first', 'second'])

# %%
{}.fromkeys(['first', 'second'])

# %% [markdown]
# Combining dictionaries

# %%
d1 = {'a':1}
d2 = {'a':2, 'b':2}
d1.update(d2)
d1['a']
d2['b']

# %%
d1 = {'a':1}
d2 = {'b':2, 'c':3}

print('d1:', d1)
print('d2:', d2)

d1.update(d2)
print('d1 sau khi update:', d1)

# %%
t = {'a': 1, 'b': 2}
# [x for x in t.itervalues()]
# [x for x in t.iterkeys()]
# [x for x in t.iteritems()]
# https://stackoverflow.com/questions/30418481/error-dict-object-has-no-attribute-iteritems
[x for x in t.values()]
[x for x in t.keys()]
[x for x in t.items()]

# %%
l_keys   = ['a', 'b', 'c', 'd', 'e']
l_values = [1, 2, 3, 4, 5]

d = {(k,v) for (k,v) in zip(l_keys,l_values)}
print(d)

# %%
# dic comprehension

aDict = {str(i):i for i in range(5)}
print(aDict)

# %%
# from zip

tuple1 = (1, 2, 3)
tuple2 = (4, 5, 6)

a_dict = dict(zip(tuple1, tuple2))
print(type(a_dict))
print(a_dict)

# %%
# from zip

set1 = {1, 2, 3}
set2 = {4, 5, 6}

a_dict = dict(zip(set1, set2))
print(type(a_dict))
print(a_dict)

# %%
# from zip

list1 = [1, 2, 3]
list2 = [4, 5, 6]

a_dict = dict(zip(list1, list2))
print(type(a_dict))
print(a_dict)

# %%
# setdefault()

fruits = {'banana': 2}
fruits.setdefault('apple', 0)

print(fruits)

# %%
# setdefault()

fruits = {'banana': 2, 'apple': 4}
fruits.setdefault('apple', 0)

print(fruits)

# %%
# setdefault()

fruits = {'banana': 2}
fruits.setdefault('apple', 0)

fruits['apple'] += 10
print(fruits)

# %%
# setdefault()

fruits = {'banana': 2}

fruits['apple'] += 10
print(fruits)

# %%
# merge two dicts
cereal = {"oat":3, "wheat":1,"corn":6}
fruits = {"banana": 2, 'apple': 4}
result = {**fruits, **cereal}
result
# print(**result) # cannot print

# %%
# merge two dicts

fruits = {'banana': 2, 'apple': 4}
cereal = {'rice': 3, 'corn': 7}

result = {**fruits, **cereal}
print(result)

# %%
# check if a key exists

fruits = {'banana': 2, 'apple': 4}

print('apple' in fruits)
print('corn' in fruits)

# %%
# remove empty items

fruits = {'banana': 2, 'apple': None}

dict1 = {key:value for (key, value)
                     in fruits.items()
                     if value is not None}
print(dict1)

# %%
# access value via key

fruits = {'banana': 2, 'apple': 4}
print(fruits.get('apple'))
print(fruits.get('corn'))

# %%
# access value via key

fruits = {'banana': 2, 'apple': 4}
print(fruits['apple'])
print(fruits['corn'])

# %% [markdown]
# Dictionary and File

# %%
import json

parameters = {'learning_rate': 0.1,
              'optimizer': 'Adam',
              'metric': 'Accuracy'}

with open('data.json', 'w') as fp:
    json.dump(parameters, fp)

# %%
with open('data.json', 'r') as fp:
    data = json.load(fp)
    print(data)

# %%
print(data['learning_rate'])

# %% [markdown]
# Iterables and Sorting

# %%
# create a list
aList = [1, 5, 3, 7, 4]
print(aList)

# sort
sortedList = sorted(aList)
print(sortedList)

# %%
# create a list
aList = [1, 5, 3, 7, 4]
print(aList)

# function for sorting
def compare(item):
    return item

# sort
sortedList = sorted(aList, key=compare)
print(sortedList)

# %%
# data
list1 = [1, 5, 3, 7, 4]
list2 = [16, 13, 18, 11, 15]

# create a dictionary
dictionary = dict(zip(list1, list2))
print(dictionary)

# %%
sortedDict = sorted(dictionary)
print(sortedDict)

# %%
# data
list1 = ['a', 'g', 'e', 'h', 'b']
list2 = [16, 13, 18, 11, 15]

# create a dictionary
list3 = list(zip(list1, list2))
print(list3)

# %%
list4 = sorted(list3)
print(list4)

# %%
# data
list1 = ['a', 'g', 'e', 'h', 'b']
list2 = [16, 13, 18, 11, 15]

# function for sorting
def compare(item):
    return item[0]

# create a dictionary
list3 = list(zip(list1, list2))
print(list3)

# %%
list4 = sorted(list3, key=compare)
print(list4)

# %%
# data
list1 = ['a', 'g', 'e', 'h', 'b']
list2 = [16, 13, 18, 11, 15]

# function for sorting
def compare(item):
    return item[1]

# create a dictionary
list3 = list(zip(list1, list2))
print(list3)

# %%
list4 = sorted(list3, key=compare)
print(list4)

# %%
# data
list1 = ['a', 'g', 'e', 'h', 'b']
list2 = [16, 13, 18, 11, 15]

# create a dictionary
list3 = list(zip(list1, list2))
print(list3)

# %%
list4 = sorted(list3, key=lambda item: item[1])
print(list4)

# %% [markdown]
# ## **Application**

# %% [markdown]
# ###

# %% [markdown]
# ### 3.1.IOU_Tuple

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
def computeIoU(boxA, boxB):
    # determine the (x, y) coordinates of the intersection rectangle
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])

    # compute the area of intersection rectangle
    interArea = max(0, xB - xA + 1) * max(0, yB - yA + 1)

    # compute the area of both the prediction and ground-truth
    # rectangles
    boxAArea = (boxA[2] - boxA[0] + 1) * (boxA[3] - boxA[1] + 1)
    boxBArea = (boxB[2] - boxB[0] + 1) * (boxB[3] - boxB[1] + 1)

    # compute the intersection over union by aking the intersection
    # area and dividing it by the sum of prediction + ground-truth
    # areas - the inersection area
    iou = interArea / float(boxAArea + boxBArea - interArea)

    # return the intersection over union value
    return iou

# %%
boxA = (0,0,5,5)
boxB = (2.5, 2.5, 7.5, 7.5)
error = computeIoU(boxA, boxB)
print(error)

# %% [markdown]
# ### 3.2. Dictionary_ImageHistogram

# %%
import cv2
# from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import sys

cat_image = cv2.imread("binary_cat.png",0) # GRAY
print(cat_image.shape)
if cat_image is None:
    sys.exit("Image not exist or wrong path!")

imgrgb = cv2.cvtColor(cat_image, cv2.COLOR_BGR2RGB)
plt.imshow(imgrgb)
plt.axis("off")
plt.show()

# %%
counts = dict()
height, width = cat_image.shape
for row in range(height):
    for col in range(width):
        counts[cat_image[row, col]] = counts.get(cat_image[row, col],0) + 1

print('Counts', counts)

# %%
import matplotlib.pyplot as plt

names = list(counts.keys())
values = list(counts.values())

plt.bar(range(len(counts)), values, tick_label=names)
plt.show()

# %% [markdown]
# ### 4.1 NMS_List_Tuple

# %%
import numpy as np

# %%
def non_max_suppression(boxes, overLapThresh):
    # if there are no boxes, return the empty list
    if len(boxes) == 0:
        return []

    # Initialize the list of picked indexes
    pick = []

    # Grab the coordinates of the bounding boxes
    x1 = boxes[:, 0]
    y1 = boxes[:, 1]
    x2 = boxes[:, 2]
    y2 = boxes[:, 3]
    c = boxes[:, 4]

    # Compute the area of the bounding boxes and sort the bounding boxes
    #  by the bottom right y coordinate of the bounding boxes
    area = (x2 - x1 + 1) * (y2 - y1 + 1)
    idxs = np.argsort(c)

    # Keep looping while some indexes still remain in the indexes list
    while len(idxs) > 0:
        # Grab the last index in the indexes list and add the index value
        # to the list of picked indexes
        last = len(idxs) - 1
        i = idxs[last]
        pick.append(i)

        # Find the largest (x, y) coordinates for the start of
        # the bounding boxes and the smallest (x, y) coordinates
        # for the end of the bounding boxes

        # The maximum is equivalent to np.where(x1 >= x2, x1, x2)
        # when neither x1 nor x2 are nans,
        # but it is faster and does proper broadcasting
        xx1 = np.maximum(x1[i], x1[idxs[:last]])
        yy1 = np.maximum(y1[i], y1[idxs[:last]])
        xx2 = np.maximum(x2[i], x2[idxs[:last]])
        yy2 = np.maximum(y2[i], y2[idxs[:last]])

        # Compute the width and the height of the bounding boxes
        w = np.maximum(0, xx2 - xx1 + 1)
        h = np.maximum(0, yy2 - yy1 + 1)

        #  Compute the ratio of overlap
        overlap = (w * h) / area[idxs[:last]]

        # Delete all indexes from the index list that have
        idxs = np.delete(idxs, np. concatenate((
            [last],
            np.where(overlap > overLapThresh)[0]
        )))
        #  Return only the bounding boxes that were picked using
        # the integer type
        return boxes[pick].astype("int")

# %%
#  import the necessary packages
import numpy as np
import cv2
import sys
# from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

bounding_boxes = np.array(
    [
        (12, 84, 140, 212, 0.3),
        (24, 84, 152, 212, 0.4),
        (36, 84, 164, 212, 0.5),
        (12, 96, 140, 224, 0.6),
        (24, 96, 152, 224, 0.7),
        (24, 108, 152, 236, 0.8)
    ]
)

# Load the image and clone it
image = cv2.imread("cat_nms.png")
if image is None:
    sys.exit("Image not exist or wrong path. Please recheck!")
orig = image.copy()

# Loop over the bounding boxes for each image and draw them
for (start_x, start_y, end_x, end_y, confidence) in bounding_boxes:
    cv2.rectangle(
        orig, #
        (int(start_x), int(start_y)), #
        (int(end_x), int(end_y)), #
        (0, 0, 255), #
        2 #
    )

# Perform non-maximum suppression on the bounding boxes
pick = non_max_suppression(bounding_boxes, overLapThresh=0.3)

# Loop over the picked bounding boxes and draw them
for (start_x, start_y, end_x, end_y, confidence) in pick:
    print(start_x, start_y, end_x, end_y, confidence)
    cv2.rectangle(
        image,
        (start_x, start_y),
        (end_x, end_y),
        (0, 0, 255),
        2
    )

# Display the image
# cv2_imshow(orig)
# cv2_imshow(image)
plt.imshow(orig)
plt.axis("off")
plt.show()

# %%
plt.imshow(image)
plt.axis("off")
plt.show()

# %% [markdown]
# ## Friday practice

# %% [markdown]
# 1. String

# %%
# create a string
name = 'AI'
print(name)

# %%
# iterate a string
name = 'AI'
for character in name:
    print(character)

# %%
# iterate a string
name = 'AI'
length = 2

for index in range(length):
    print(name[index])

# %% [markdown]
# List

# %%
# create a list int elements
l = [1, 2,2]
l = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# get forward index
print(l[0])
print(l[1])

# get backward index
print(l[-1])
print(l[-2])

# %%
n1 = 5
n2 = 8

l1 = [n1]
l2 = [n1,n2]

print(l1)
print(l2)

# %%
# create list
# range([start,] stop [, step])
l = []

for i in range(10):
    l = l + [i]

# %%
l1 = []
for i in range(100):
    l.append(i)

l2 = [i for i in range(100)]

l3 = list(range(100))

print("l1: ", l1)
print("l2: ", l2)
print("l3: ", l3)

# %%
a = range(10)
print(type(a))
print(a[0])

b = []
print(type(b))

# %%
import random

l = [random.randint(1,100) for i in range(10)]
print(l)
# only use the method of getting elements in the list based on index,
# and basic functions for lists such as append
# thinking and solving these exercises yourself will help you improve
# your programming thinking ability

# %%
import numpy as np
# exercise 1: find the max and min values of list l
# test set: max([1,5,7,3]) --> 7
# test set: min([1,5,7,3]) --> 1

maxval = np.max(l)
minval = np.min(l)

print("max = ", maxval)
print("min = ", minval)

# %%
# exercise 2: use any method you know or can deduce, sort (arrange)
# the elements in list l so that the elements have increasing (and decreasing) values
# test set: sort_increasing([1,5,7,3]) --> [1,3,5,7]
# test set: sort_reducing([1,5,7,3]) --> [7,5,3,1]
import numpy as np

data_inscrease = np.sort(l)
data_descrease = data_inscrease[::-1]

print("data_inscrease = ", data_inscrease)
print("data_descrease = ", data_descrease)

# %%
import random

l = [random.randint(1,100) for i in range(10)]
print(l)

# %%
# exercise 3: shuffle the positions of the elements in the list.
# (this operation is often used before feeding data into training)
# test set: permutate([1,5,7,3]) --> can be [5,7,3,1]
import numpy as np
data_shuffle = np.copy(l)
np.random.shuffle(data_shuffle)
print(data_shuffle)
print(l)
print(type(data_shuffle))
print(type(l))

# %%
# list slicing
# We can get multiple elements in the list using the syntax
# get elements in the list from start position to (end-1) position with step jump
# return value is a list

# %%
l = [i for i in range(10)]

# %%
# Exercise for lis slicing
# Exercise 1: get all elements
print(l)
print(l[:])
print(l[::])
# Exercise 2: get elements at index 0,2
print(l[:3:2])
# Exercise 3: get elements at indexes 2,3,4
print(l[2:5])
# Exercise 4: get elements from indexes 3 onwards
print(l[3:])
# Exercise 5: get elements from the beginning to index 6
print(l[:7])

# %%
l = [i for i in range(10)]

# get all elements
print(l[:])

# get all elements
print(l[0:10])

# get elements at index 0,1
print(l[0:2])

# get elements at index 1,2,3
print(l[1:4])

# get elements from index 4 onwards
print(l[4:])

# get elements from the beginning to index 5
print(l[:6])

# get all even elements
print(l[0:10:2])

# get all odd elements
print(l[1:10:2])

# %% [markdown]
# ### List - example

# %%
# change list while iterating it

# create a list of numbers
numbers = [1, 2, 3, 4, 5]

for num in numbers:
    # print the num
    print(num)

    # check if the num is equal to 3
    if (num == 3):
        # add 3 to the list
        numbers.append(3)

# %%
# copy in python

list1 = (1, 2, 3)
list2 = list1

print('tuple 1: ', list1)
print('tuple 2: ', list2)

print('tuple1 address: ', id(list1))
print('tuple2 address: ', id(list2))

# %%
list1 = [1, 2, 3, 4, 5]
list2 = list1

print('List 1: ', list1)
print('List 2: ', list2)

list1[3] = 9
print('List 1: ', list1)
print('List 2: ', list2)

print('List1 address: ', id(list1))
print('List2 address: ', id(list2))

# %%
import copy

list1 = [1, 2, 3, 4, 5]
list2 = copy.copy(list1)

print('List 1: ', list1)
print('List1 address: ', id(list1))
print('List 2: ', list2)
print('List2 address: ', id(list2))

print()
list1[3] = 9
print('List 1: ', list1)
print('List 2: ', list2)

# %%
import copy

list1 = [[1, 2], 3]
list2 = copy.copy(list1)

print('List 1: ', list1)
print('List1 address: ', id(list1))
print('List 2: ', list2)
print('List2 address: ', id(list2))

print()
print('List1[0] address: ', id(list1[0]))
print('List2[0] address: ', id(list2[0]))

print()
list1[0][0] = 9
print('List1[0][0] address: ', id(list1[0][0]))
print('List2[0][0] address: ', id(list2[0][0]))
print('List 1: ', list1)
print('List 2: ', list2)
# so now how can we resolve this problem?

# %%
import copy

list1 = [[1, 2], 3]
list2 = copy.deepcopy(list1)

print('List 1: ', list1)
print('List1 address: ', id(list1))

print('List 2: ', list2)
print('List2 address: ', id(list2))

print()
print('List1[0] address: ', id(list1[0]))
print('List2[0] address: ', id(list2[0]))

print()
list1[0][0] = 9
print('List1[0][0] address: ', id(list1[0][0]))
print('List2[0][0] address: ', id(list2[0][0]))
print('List 1: ', list1)
print('List 2: ', list2)

# %% [markdown]
# ### Slide example 2

# %%
data = [6, 5, 7, 1, 9, 2]
print(data)
data.append(4)
print(data)

# %%
data = [6, 5, 7, 1, 9, 2]
print(data)
data.insert(0, 4)
print(data)

# %%
data = [6, 5, 7, 1, 9, 2]
print(data)
data[1] = 4
print(data)

# %%
data = [6, 5, 7, 1]
print(data)
data.extend([9, 2])
print(data)

# %%
data1 = [6, 5, 7]
data2 = [1, 9, 2]

# concatenate
data = data1 + data2
print(data)

# %%
data = [6, 5]

# multiply with a number
data_m = data*3
print(data_m)

# %%
data = [6, 5, 7, 1, 9, 2]
print(data)
data.sort()
print(data)

# %%
data = [6, 5, 7, 1, 9, 2]
print(data)
data.sort(reverse = True)
print(data)

# %%
data = [6, 5, 7, 1, 9, 2]
print(data)
data.pop(2)  # by index
print(data)

# %%
data = [6, 5, 7, 1, 9, 2]
print(data)
data.remove(2) # by value
print(data)

# %%
data = [6, 5, 2, 1, 9, 2]
print(data)
data.remove(2) # by value
print(data)

# %%
data = [6, 5, 7, 1, 9, 2]
print(data)

del data[1:3]
print(data)

# %%
data = [6, 5, 7, 1, 9, 2]
print(data)

data.clear()
print(data)

# %%
data = [6, 5, 7, 1, 9, 2]
print(data)

indexOf9 = data.index(9)
print(indexOf9)

# %%
data = [6, 5, 7, 1, 9, 2]
print(data)

data.reverse()
print(data)

# %%
data = [6, 5, 7, 1, 9, 2]
print(data)

numOf7 = data.count(7)
print(numOf7)

# %%
data = [6, 5, 7, 1, 9, 2]
print(data)

aCopy = data.copy()
print(aCopy)

# %%
data = [6, 5, 7, 1, 9, 2]
print(data)
# get a number of elements
length = len(data)
print(length)
# get the min and max values
print(min(data))
print(max(data))

# %%
data = [6, 5, 7, 1, 9, 2]
print(data)

summation = sum(data)
print(summation)

# %%
# custom summation - way 1
def computeSummation(data):
    result = 0

    for value in data:
        result = result + value

    return result

# test
data = [6, 5, 7, 1, 9, 2]
summation = computeSummation(data)
print(summation)

# %%
# custom summation - way 2
def computeSummation(data):
    result = 0

    length = len(data)
    for index in range(length):
        result = result + data[index]

    return result

# test
data = [6, 5, 7, 1, 9, 2]
summation = computeSummation(data)
print(summation)

# %%
data = [6, 5, 7, 1, 9, 2]
summation = sum(data)
print(summation)

# %%
# sum of even number
def sum1(data):
    result = 0

    for value in data:
        if value%2 == 0:
            result = result + value

    return result

# test
data = [6, 5, 7, 1, 9, 2]
summation = sum1(data)
print(summation)

# %%
# sum of numbers with even indices
def sum2(data):
    result = 0

    length = len(data)
    for index in range(length):
        if index%2 == 0:
            result = result + data[index]

    return result

# test
data = [6, 5, 7, 1, 9, 2]
summation = sum2(data)
print(summation)

# %%
# sorted
data = [6, 5, 7, 1, 9, 2]
print(data)

sorted_data = sorted(data)
print(sorted_data)

# %%
# sorted
data = [6, 5, 7, 1, 9, 2]
print(data)

sorted_data = sorted(data, reverse=True)
print(sorted_data)

# %% [markdown]
# List comprehension

# %%
# square function
def square(data):
    result = []

    for value in data:
        result.append(value*value)

    return result

# test
data = [6, 5, 7, 1, 9, 2]
print(data)
data_s = square(data)
print(data_s)

# %%
# using list comprehension
def square(data):
    result = [value*value for value in data]

    return result

# test
data = [6, 5, 7, 1, 9, 2]
print(data)
data_s = square(data)
print(data_s)

# %%
import math

# sigmoid function
def sigmoid(x):
    result = 1 / (1 + math.exp(-x))
    return result

def sigmoidForList(data):
    result = [sigmoid(x) for x in data]
    return result

# test
data = [1, 5, -4, 3, -2]
print(data)
data_a = sigmoidForList(data)
print(data_a)

# %%
def relu(x):
    result = 0
    if x > 0:
        result = x

    return result

def reluForList(data):
    result = [relu(x) for x in data]
    return result

# test
data = [1, 5, -4, 3, -2]
print(data)
data_a = reluForList(data)
print(data_a)

# %%
# relu function
def relu(data):
    result = [x if x>0 else 0 for x in data]
    return result

# test
data = [1, 5, -4, 3, -2]
print(data)
data_a = relu(data)
print(data_a)

# %%
# quiz 1
data = [1, 5, -4, 3, -2]
print(data)

data_a = [x if x>0 else 0 for x in data]
print(data_a)

# %%
# quiz 2
data = [1, 5, -4, 3, -2]
print(data)

data_a = [x if x>0 for x in data]
print(data_a)

# %%
# quiz 3
data = [1, 5, -4, 3, -2]
print(data)

data_a = [x for x in data if x>0]
print(data_a)

# %%
# quiz 4
data = [1, 5, -4, 3, -2]
print(data)

data_a = [x for x in data if x>0 else 0]
print(data_a)

# %% [markdown]
# Mutable and Immutable

# %%
# immutable
def square(data):
    result = []
    for value in data:
        result.append(value*value)

    return result

# test
data = [6, 5, 7, 1, 9, 2]
print(data)

data_s = square(data)
print(data_s)

# %%
# mutable
def square(data):
    length = len(data)

    for i in range(length):
        value = data[i]
        data[i] = value*value

# test
data = [6, 5, 7, 1, 9, 2]
print(data)

square(data)
print(data)

# %%
l1 = [1, 2, 3]
l2 = [5, 6, 7]

# print in pairs
length = len(l1)
for i in range(length):
    print(l1[i], l2[i])

# %%
l1 = [1, 2, 3]
l2 = [5, 6, 7]

# print in pairs
for v1, v2 in zip(l1, l2):
    print(v1, v2)

# %%
# for and list
data = [6, 1, 7]
for value in data:
    print(value)

# %%
# reversed
data = [6, 1, 7]
for value in reversed(data):
    print(value)

# %%
# get index and value
data = [6, 1, 7]

length = len(data)
for index in range(length):
    print(index, data[index])

# %%
# enumerate
data = [6, 1, 7]
for index, value in enumerate(data):
    print(index, value)

# %% [markdown]
# Converting to List

# %%
name = 'AI'
data = list(name)

print(name)
print(data)

# %%
data = list(range(4, 10))
print(data)

# %% [markdown]
# Integral

# %%
import random

def generateList(a, b):
    result = []
    for _ in range(10):
        num = random.randint(a, b)
        result.append(num)

    return result
data = generateList(1, 5)
print(data)

# %%
def accumulate(data):
    result = []
    result.append(data[0])

    length = len(data)
    for i in range(1, length):
        result.append(data[i] + result[i-1])

    return result

result = accumulate(data)
print(result)

# %%
k = 2
f6 = result[6+k] - result[6-k-1]
print(f6)

# %% [markdown]
# quiz

# %%
data = [1, 2, 3]
data[1] = 5
print(data)

# %%
data = []
data[1] = 5
print(data)

# %%
import random

data = []

for _ in range(10):
    data.append(random.randint(1, 1))

print(data)

# %%
def accumulate(fdata):
    Fdata = []
    # for the first position
    Fdata.append(fdata[0])
    #Fdata[x] = Fdata[x-1] + fdata[x]
    length = len(fdata)
    for x in range(1, length):
        Fdata.append(Fdata[x-1] + fdata[x])

    return Fdata

Fdata = accumulate(data)
print(Fdata)
k = 2
x = 5
s = Fdata[x+k] - Fdata[x-k-1]
print(s)
