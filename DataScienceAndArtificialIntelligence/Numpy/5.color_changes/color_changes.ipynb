# %%
import cv2
import matplotlib.pyplot as plt

# Read the image
image = cv2.imread('image1.png', 1)
print(image.shape)
print(image.dtype)
# Out:
# (162, 311, 3)
# uint8

# %%
import numpy as np

data = np.array([1, 2.5])
print(data.dtype)

data = data.astype(np.uint8)
print(data.dtype)
# Out:
# float64
# uint8

# %%
import numpy as np

data = np.array([0, 200])
data = data.astype(np.uint8)
print(data)

data = data + 100
print(data)
# Out:
# [  0 200]
# [100  44]

# %% [markdown]
# ### Color transformation

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('image1.png')
image = image + 100

# convert and save
cv2.imwrite('output1.png', image)
# Out:
# True

# %%
image = cv2.imread('image1.png', flags=cv2.IMREAD_COLOR)
image = np.where(image + 100 > 255,
                 255, image + 100)
cv2.imwrite('output2.png', image)
# Out:
# True

# %%
image = cv2.imread('image1.png', flags=cv2.IMREAD_COLOR)#1
image = np.where(image.astype(float) + 100 > 255,
                 255, image + 100)

# Convert and save
cv2.imwrite('output3.png', image)
# Out:
# True

# %%
image = cv2.imread('image1.png', flags=cv2.IMREAD_COLOR)#1
image = image.astype(float)

image = image + 100
image = np.clip(image, 0, 255)
image = image.astype(np.uint8)

image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
image = cv2.imread('image1.png', flags=cv2.IMREAD_COLOR)#1
image = image.astype(float)
image = image + 100
image = np.where(image > 255, 255, image)
image = image.astype(np.uint8)

image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
image = cv2.imread('image1.png', flags=cv2.IMREAD_COLOR)#1
# image = image.astype(float)
# image = image + 100
image = np.where(image + 100 > 255,
                 255,
                 image)
# image = image.astype(np.uint8)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.axis('off')
plt.show()
